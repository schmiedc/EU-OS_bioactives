# %%
from datetime import date
import pandas as pd
import os
import glob

# %% [markdown]
# # Load data

# %%
parent_directory = "/home/schmiedc/FMP_Docs/Projects/Bioactives_data/"

# Path 
data_path =  parent_directory  + "aggregated_data/IMTM_HepG2/"
save_path = parent_directory  + "results/"
annot_path = parent_directory  + "annotations/"

# %%
### loading latest data
Data = []
plates = ["B1001","B1002","B1003","B1004","B1005","B1006","B1007"]
batches = ["R1", "R2", "R3", "R4"]
path = data_path

for batch in batches:
    for plate in plates:
    
        file_type = '/*[0-9]_HepG2_10uM_*' + plate + "_" + batch + "_CP_Profiles_Aggregated.csv"
        
        files_temp = glob.glob(path + file_type)
        max_file = max(files_temp, key=os.path.getctime)
    
        ### load file
        Data_Temp = pd.read_csv(max_file)
        print(batch, plate, "has shape", Data_Temp.shape)  
        ### put to list
        Data.append(Data_Temp)

### concat all batches together
Data_aggregated = pd.concat(Data)
Data_aggregated = Data_aggregated.reset_index(drop = True)

print("Aggregated Data has shape ", Data_aggregated.shape)
# Out:
# R1 B1001 has shape (378, 2981)
# R1 B1002 has shape (382, 2981)
# R1 B1003 has shape (384, 2981)
# R1 B1004 has shape (379, 2981)
# R1 B1005 has shape (379, 2981)
# R1 B1006 has shape (381, 2981)
# R1 B1007 has shape (380, 2981)
# R2 B1001 has shape (379, 2981)
# R2 B1002 has shape (384, 2981)
# R2 B1003 has shape (383, 2981)
# R2 B1004 has shape (380, 2981)
# R2 B1005 has shape (382, 2981)
# R2 B1006 has shape (380, 2981)
# R2 B1007 has shape (381, 2981)
# R3 B1001 has shape (379, 2981)
# R3 B1002 has shape (382, 2981)
# R3 B1003 has shape (382, 2981)
# R3 B1004 has shape (381, 2981)
# R3 B1005 has shape (380, 2981)
# R3 B1006 has shape (381, 2981)
# R3 B1007 has shape (381, 2981)
# R4 B1001 has shape (383, 2981)
# R4 B1002 has shape (383, 2981)
# R4 B1003 has shape (384, 2981)
# R4 B1004 has shape (378, 2981)
# R4 B1005 has shape (379, 2981)
# R4 B1006 has shape (381, 2981)
# R4 B1007 has shape (382, 2981)
# Aggregated Data has shape  (10668, 2981)

# %%
Data_aggregated.head()
# Out:
#   Metadata_Batch Metadata_Plate Metadata_Well  Metadata_Object_Count  \
# 0     HepG2_10uM       B1001_R1           A01                    401
# 1     HepG2_10uM       B1001_R1           A02                    960
# 2     HepG2_10uM       B1001_R1           A03                    684
# 3     HepG2_10uM       B1001_R1           A04                   1085
# 4     HepG2_10uM       B1001_R1           A05                     91
#
#    Nuc_AreaShape_Area  Nuc_AreaShape_BoundingBoxArea  \
# 0               443.0                          600.0
# 1               358.0                          484.0
# 2               390.5                          546.0
# 3               368.0                          506.0
# 4               378.0                          567.0
#
#    Nuc_AreaShape_BoundingBoxMaximum_X  Nuc_AreaShape_BoundingBoxMaximum_Y  \
# 0                               544.0                               521.0
# 1                               533.0                               532.0
# 2                               543.5                               519.0
# 3                               467.0                               529.0
# 4                               339.0                               443.0
#
#    Nuc_AreaShape_BoundingBoxMinimum_X  Nuc_AreaShape_BoundingBoxMinimum_Y  \
# 0                               519.0                               494.0
# 1                               507.5                               509.0
# 2                               518.5                               496.0
# 3                               445.0                               502.0
# 4                               319.0                               423.0
#
#    ...  Cyto_Texture_Variance_Mito_10_02_256  \
# 0  ...                             27.485077
# 1  ...                             18.149014
# 2  ...                             44.836899
# 3  ...                             12.584591
# 4  ...                             79.650978
#
#    Cyto_Texture_Variance_Mito_10_03_256  Cyto_Texture_Variance_Mito_3_00_256  \
# 0                             27.159029                            27.034550
# 1                             18.117806                            17.896635
# 2                             42.719259                            45.046219
# 3                             12.365254                            12.947254
# 4                             68.290535                            73.153893
#
#    Cyto_Texture_Variance_Mito_3_01_256  Cyto_Texture_Variance_Mito_3_02_256  \
# 0                            27.474699                            27.517895
# 1                            17.961329                            18.167331
# 2                            44.485645                            46.066105
# 3                            12.847301                            13.083285
# 4                            76.065323                            73.855774
#
#    Cyto_Texture_Variance_Mito_3_03_256  Cyto_Texture_Variance_Mito_5_00_256  \
# 0                            27.098289                            27.044748
# 1                            17.974684                            17.838051
# 2                            44.490707                            43.116350
# 3                            12.951762                            12.947011
# 4                            75.632614                            75.405464
#
#    Cyto_Texture_Variance_Mito_5_01_256  Cyto_Texture_Variance_Mito_5_02_256  \
# 0                            27.476479                            27.397701
# 1                            18.096688                            18.167415
# 2                            43.774080                            45.156351
# 3                            12.526472                            12.824263
# 4                            80.695778                            79.210136
#
#    Cyto_Texture_Variance_Mito_5_03_256
# 0                            26.846224
# 1                            18.078164
# 2                            43.194946
# 3                            13.057779
# 4                            76.293587
#
# [5 rows x 2981 columns]

# %%
# create correct metadata columns
metadataCol = Data_aggregated['Metadata_Plate'].str.split("_", n=1, expand=True)
metadataCol[1] = metadataCol[1].astype(str)
metadataCol = metadataCol.rename(columns={0: "Metadata_Plate", 1: "Metadata_Batch"})
metadataCol
# Out:
#       Metadata_Plate Metadata_Batch
# 0              B1001             R1
# 1              B1001             R1
# 2              B1001             R1
# 3              B1001             R1
# 4              B1001             R1
# ...              ...            ...
# 10663          B1007             R4
# 10664          B1007             R4
# 10665          B1007             R4
# 10666          B1007             R4
# 10667          B1007             R4
#
# [10668 rows x 2 columns]

# %%
# drop faulty metadata columns
Data_aggregated_dropped = Data_aggregated.drop(['Metadata_Batch', 'Metadata_Plate'], axis=1)

# %%
Data_aggregated = pd.concat([metadataCol, Data_aggregated_dropped], axis=1)
print("Aggregated Data has shape ", Data_aggregated.shape)
Data_aggregated.head()
# Out:
# Aggregated Data has shape  (10668, 2981)
#   Metadata_Plate Metadata_Batch Metadata_Well  Metadata_Object_Count  \
# 0          B1001             R1           A01                    401
# 1          B1001             R1           A02                    960
# 2          B1001             R1           A03                    684
# 3          B1001             R1           A04                   1085
# 4          B1001             R1           A05                     91
#
#    Nuc_AreaShape_Area  Nuc_AreaShape_BoundingBoxArea  \
# 0               443.0                          600.0
# 1               358.0                          484.0
# 2               390.5                          546.0
# 3               368.0                          506.0
# 4               378.0                          567.0
#
#    Nuc_AreaShape_BoundingBoxMaximum_X  Nuc_AreaShape_BoundingBoxMaximum_Y  \
# 0                               544.0                               521.0
# 1                               533.0                               532.0
# 2                               543.5                               519.0
# 3                               467.0                               529.0
# 4                               339.0                               443.0
#
#    Nuc_AreaShape_BoundingBoxMinimum_X  Nuc_AreaShape_BoundingBoxMinimum_Y  \
# 0                               519.0                               494.0
# 1                               507.5                               509.0
# 2                               518.5                               496.0
# 3                               445.0                               502.0
# 4                               319.0                               423.0
#
#    ...  Cyto_Texture_Variance_Mito_10_02_256  \
# 0  ...                             27.485077
# 1  ...                             18.149014
# 2  ...                             44.836899
# 3  ...                             12.584591
# 4  ...                             79.650978
#
#    Cyto_Texture_Variance_Mito_10_03_256  Cyto_Texture_Variance_Mito_3_00_256  \
# 0                             27.159029                            27.034550
# 1                             18.117806                            17.896635
# 2                             42.719259                            45.046219
# 3                             12.365254                            12.947254
# 4                             68.290535                            73.153893
#
#    Cyto_Texture_Variance_Mito_3_01_256  Cyto_Texture_Variance_Mito_3_02_256  \
# 0                            27.474699                            27.517895
# 1                            17.961329                            18.167331
# 2                            44.485645                            46.066105
# 3                            12.847301                            13.083285
# 4                            76.065323                            73.855774
#
#    Cyto_Texture_Variance_Mito_3_03_256  Cyto_Texture_Variance_Mito_5_00_256  \
# 0                            27.098289                            27.044748
# 1                            17.974684                            17.838051
# 2                            44.490707                            43.116350
# 3                            12.951762                            12.947011
# 4                            75.632614                            75.405464
#
#    Cyto_Texture_Variance_Mito_5_01_256  Cyto_Texture_Variance_Mito_5_02_256  \
# 0                            27.476479                            27.397701
# 1                            18.096688                            18.167415
# 2                            43.774080                            45.156351
# 3                            12.526472                            12.824263
# 4                            80.695778                            79.210136
#
#    Cyto_Texture_Variance_Mito_5_03_256
# 0                            26.846224
# 1                            18.078164
# 2                            43.194946
# 3                            13.057779
# 4                            76.293587
#
# [5 rows x 2981 columns]

# %% [markdown]
# # Load EOS number

# %%
file_type = '/*[0-9]_' + 'Annotation2_IMTM_HepG2.csv'
files = glob.glob(annot_path + file_type)

### gets latest file
max_file = max(files, key=os.path.getctime)

### load file
Annotation_Bioactives = pd.read_csv(max_file)
Annotation_Bioactives.shape
# Out:
# (10752, 6)

# %%
Annotation_Bioactives.head()
# Out:
#   Metadata_Plate Metadata_Well Metadata_EOS  Metadata_Concentration  \
# 0          B1001           A01    EOS100001                      10
# 1          B1001           A02    EOS100089                      10
# 2          B1001           A03    EOS100009                      10
# 3          B1001           A04    EOS100097                      10
# 4          B1001           A05    EOS100017                      10
#
#   Metadata_Partner Metadata_Batch
# 0             IMTM             R4
# 1             IMTM             R4
# 2             IMTM             R4
# 3             IMTM             R4
# 4             IMTM             R4

# %% [markdown]
# # Merge with EOS number

# %%
Data_Bioactives = pd.merge(
    Annotation_Bioactives, 
    Data_aggregated, 
    on = ["Metadata_Batch", "Metadata_Plate", "Metadata_Well"], 
    how = "inner")
        
print("Aggregated and annotated Data has shape ", Data_Bioactives.shape)
# Out:
# Aggregated and annotated Data has shape  (10668, 2984)

# %%
Data_Bioactives.head()
# Out:
#   Metadata_Plate Metadata_Well Metadata_EOS  Metadata_Concentration  \
# 0          B1001           A01    EOS100001                      10
# 1          B1001           A02    EOS100089                      10
# 2          B1001           A03    EOS100009                      10
# 3          B1001           A04    EOS100097                      10
# 4          B1001           A05    EOS100017                      10
#
#   Metadata_Partner Metadata_Batch  Metadata_Object_Count  Nuc_AreaShape_Area  \
# 0             IMTM             R4                   1100               376.0
# 1             IMTM             R4                    387               377.0
# 2             IMTM             R4                   1300               366.0
# 3             IMTM             R4                   1116               381.0
# 4             IMTM             R4                   1242               387.0
#
#    Nuc_AreaShape_BoundingBoxArea  Nuc_AreaShape_BoundingBoxMaximum_X  ...  \
# 0                          512.5                               511.0  ...
# 1                          513.0                               489.0  ...
# 2                          504.0                               488.5  ...
# 3                          523.5                               488.5  ...
# 4                          529.0                               456.5  ...
#
#    Cyto_Texture_Variance_Mito_10_02_256  Cyto_Texture_Variance_Mito_10_03_256  \
# 0                             22.554693                             21.714226
# 1                             13.415397                             13.543335
# 2                             25.212769                             24.695880
# 3                             21.606750                             21.524075
# 4                             35.863705                             36.348848
#
#    Cyto_Texture_Variance_Mito_3_00_256  Cyto_Texture_Variance_Mito_3_01_256  \
# 0                            22.126733                            21.706818
# 1                            13.185762                            13.186164
# 2                            24.789306                            24.868424
# 3                            21.300508                            21.288512
# 4                            40.826340                            40.014950
#
#    Cyto_Texture_Variance_Mito_3_02_256  Cyto_Texture_Variance_Mito_3_03_256  \
# 0                            22.747998                            22.737820
# 1                            13.742171                            13.480765
# 2                            25.526916                            25.174773
# 3                            21.769292                            21.288239
# 4                            41.604687                            40.418741
#
#    Cyto_Texture_Variance_Mito_5_00_256  Cyto_Texture_Variance_Mito_5_01_256  \
# 0                            22.131124                            21.774646
# 1                            13.012366                            13.521472
# 2                            24.576415                            24.249728
# 3                            20.730912                            21.357671
# 4                            37.847143                            38.026442
#
#    Cyto_Texture_Variance_Mito_5_02_256  Cyto_Texture_Variance_Mito_5_03_256
# 0                            22.613887                            22.951774
# 1                            13.688066                            13.431323
# 2                            25.125024                            24.825614
# 3                            21.432836                            21.115022
# 4                            39.940529                            38.071106
#
# [5 rows x 2984 columns]

# %% [markdown]
# # Save raw data

# %%
### 
filename = save_path + str(date.today()) + "_IMTM_HepG2_raw.csv"
Data_Bioactives.to_csv(filename, index = False)

# %% [markdown]
# ## Save missing data

# %%
Data_Bioactives_missing = pd.merge(
    Annotation_Bioactives, 
    Data_aggregated, 
    on = ["Metadata_Batch", "Metadata_Plate", "Metadata_Well"], 
    how = "left",
    indicator = True)
        
Data_Bioactives_missing = Data_Bioactives_missing[Data_Bioactives_missing["_merge"] == 'left_only'].dropna(axis='columns')

# %%
### 
filename = save_path + str(date.today()) + "_IMTM_HepG2_raw_missing_wells.csv"
Data_Bioactives_missing.to_csv(filename, index = False)

# %%
print("There are",len(Data_Bioactives_missing), "missing wells.")
# Out:
# There are 84 missing wells.

# %%
Data_Bioactives_missing_counts = Data_Bioactives_missing['Metadata_EOS'].value_counts()
print("There are",len(Data_Bioactives_missing_counts[Data_Bioactives_missing_counts.iloc[:] == 4]), "compounds missing all 4 replicates.")
# Out:
# There are 8 compounds missing all 4 replicates.
