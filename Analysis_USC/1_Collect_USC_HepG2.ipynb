# %%
from datetime import date
import pandas as pd
import os
import glob

# %% [markdown]
# # Load data

# %%
parent_directory = "/home/schmiedc/FMP_Docs/Projects/Bioactives_data/"

# Path 
data_path =  parent_directory  + "aggregated_data/USC_HepG2/"
save_path = parent_directory  + "results/"
annot_path = parent_directory  + "annotations/"

# %%
### loading latest data
Data = []
plates = ["B1001","B1002","B1003","B1004","B1005","B1006","B1007"]
batches = ["R1", "R2", "R3", "R4"]
path = data_path

for batch in batches:
    for plate in plates:
    
        file_type = '/*[0-9]_HepG2_10uM_*' + plate + "_" + batch + "_CP_Profiles_Aggregated.csv"
        
        files_temp = glob.glob(path + file_type)
        max_file = max(files_temp, key=os.path.getctime)
    
        ### load file
        Data_Temp = pd.read_csv(max_file)
        print(batch, plate, "has shape", Data_Temp.shape)  
        ### put to list
        Data.append(Data_Temp)

### concat all batches together
Data_aggregated = pd.concat(Data)
Data_aggregated = Data_aggregated.reset_index(drop = True)

print("Aggregated Data has shape ", Data_aggregated.shape)
# Out:
# R1 B1001 has shape (384, 2981)
# R1 B1002 has shape (384, 2981)
# R1 B1003 has shape (384, 2981)
# R1 B1004 has shape (384, 2981)
# R1 B1005 has shape (383, 2981)
# R1 B1006 has shape (384, 2981)
# R1 B1007 has shape (384, 2981)
# R2 B1001 has shape (384, 2981)
# R2 B1002 has shape (384, 2981)
# R2 B1003 has shape (384, 2981)
# R2 B1004 has shape (384, 2981)
# R2 B1005 has shape (383, 2981)
# R2 B1006 has shape (384, 2981)
# R2 B1007 has shape (382, 2981)
# R3 B1001 has shape (384, 2981)
# R3 B1002 has shape (384, 2981)
# R3 B1003 has shape (384, 2981)
# R3 B1004 has shape (383, 2981)
# R3 B1005 has shape (384, 2981)
# R3 B1006 has shape (384, 2981)
# R3 B1007 has shape (384, 2981)
# R4 B1001 has shape (384, 2981)
# R4 B1002 has shape (384, 2981)
# R4 B1003 has shape (384, 2981)
# R4 B1004 has shape (384, 2981)
# R4 B1005 has shape (384, 2981)
# R4 B1006 has shape (384, 2981)
# R4 B1007 has shape (384, 2981)
# Aggregated Data has shape  (10747, 2981)

# %%
Data_aggregated.head()
# Out:
#   Metadata_Batch Metadata_Plate Metadata_Well  Metadata_Object_Count  \
# 0     HepG2_10uM       B1001_R1           A01                   1188
# 1     HepG2_10uM       B1001_R1           A02                   1055
# 2     HepG2_10uM       B1001_R1           A03                    919
# 3     HepG2_10uM       B1001_R1           A04                   1820
# 4     HepG2_10uM       B1001_R1           A05                    415
#
#    Nuc_AreaShape_Area  Nuc_AreaShape_BoundingBoxArea  \
# 0               548.0                          750.0
# 1               540.0                          754.0
# 2               572.0                          805.0
# 3               458.5                          644.0
# 4               461.0                          638.0
#
#    Nuc_AreaShape_BoundingBoxMaximum_X  Nuc_AreaShape_BoundingBoxMaximum_Y  \
# 0                               567.0                               572.0
# 1                               560.0                               581.0
# 2                               558.0                               530.0
# 3                               543.5                               601.0
# 4                               528.0                               629.0
#
#    Nuc_AreaShape_BoundingBoxMinimum_X  Nuc_AreaShape_BoundingBoxMinimum_Y  \
# 0                               534.5                               536.5
# 1                               533.0                               549.0
# 2                               527.0                               503.0
# 3                               511.0                               574.5
# 4                               502.0                               602.0
#
#    ...  Cyto_Texture_Variance_Mito_10_02_256  \
# 0  ...                             33.402145
# 1  ...                             21.517467
# 2  ...                             18.503750
# 3  ...                             19.896962
# 4  ...                             51.358578
#
#    Cyto_Texture_Variance_Mito_10_03_256  Cyto_Texture_Variance_Mito_3_00_256  \
# 0                             34.362640                            32.764223
# 1                             22.041616                            20.282188
# 2                             19.005039                            17.839701
# 3                             20.077885                            19.813550
# 4                             51.549896                            49.833778
#
#    Cyto_Texture_Variance_Mito_3_01_256  Cyto_Texture_Variance_Mito_3_02_256  \
# 0                            32.971792                            33.131979
# 1                            20.300323                            20.689981
# 2                            17.912834                            17.765783
# 3                            19.387311                            19.642703
# 4                            49.990757                            50.283543
#
#    Cyto_Texture_Variance_Mito_3_03_256  Cyto_Texture_Variance_Mito_5_00_256  \
# 0                            32.626884                            32.644241
# 1                            20.434265                            20.318130
# 2                            17.722588                            17.731947
# 3                            19.443669                            19.278375
# 4                            49.137386                            49.736687
#
#    Cyto_Texture_Variance_Mito_5_01_256  Cyto_Texture_Variance_Mito_5_02_256  \
# 0                            33.476397                            33.115974
# 1                            20.990555                            20.547068
# 2                            18.489265                            17.798031
# 3                            19.548204                            19.337269
# 4                            50.390118                            49.221760
#
#    Cyto_Texture_Variance_Mito_5_03_256
# 0                            33.198650
# 1                            20.693096
# 2                            17.842939
# 3                            19.203957
# 4                            49.895370
#
# [5 rows x 2981 columns]

# %%
# create correct metadata columns
metadataCol = Data_aggregated['Metadata_Plate'].str.split("_", n=1, expand=True)
metadataCol[1] = metadataCol[1].astype(str)
metadataCol = metadataCol.rename(columns={0: "Metadata_Plate", 1: "Metadata_Batch"})
metadataCol
# Out:
#       Metadata_Plate Metadata_Batch
# 0              B1001             R1
# 1              B1001             R1
# 2              B1001             R1
# 3              B1001             R1
# 4              B1001             R1
# ...              ...            ...
# 10742          B1007             R4
# 10743          B1007             R4
# 10744          B1007             R4
# 10745          B1007             R4
# 10746          B1007             R4
#
# [10747 rows x 2 columns]

# %%
# drop faulty metadata columns
Data_aggregated_dropped = Data_aggregated.drop(['Metadata_Batch', 'Metadata_Plate'], axis=1)

# %%
Data_aggregated = pd.concat([metadataCol, Data_aggregated_dropped], axis=1)
print("Aggregated Data has shape ", Data_aggregated.shape)
Data_aggregated.head()
# Out:
# Aggregated Data has shape  (10747, 2981)
#   Metadata_Plate Metadata_Batch Metadata_Well  Metadata_Object_Count  \
# 0          B1001             R1           A01                   1188
# 1          B1001             R1           A02                   1055
# 2          B1001             R1           A03                    919
# 3          B1001             R1           A04                   1820
# 4          B1001             R1           A05                    415
#
#    Nuc_AreaShape_Area  Nuc_AreaShape_BoundingBoxArea  \
# 0               548.0                          750.0
# 1               540.0                          754.0
# 2               572.0                          805.0
# 3               458.5                          644.0
# 4               461.0                          638.0
#
#    Nuc_AreaShape_BoundingBoxMaximum_X  Nuc_AreaShape_BoundingBoxMaximum_Y  \
# 0                               567.0                               572.0
# 1                               560.0                               581.0
# 2                               558.0                               530.0
# 3                               543.5                               601.0
# 4                               528.0                               629.0
#
#    Nuc_AreaShape_BoundingBoxMinimum_X  Nuc_AreaShape_BoundingBoxMinimum_Y  \
# 0                               534.5                               536.5
# 1                               533.0                               549.0
# 2                               527.0                               503.0
# 3                               511.0                               574.5
# 4                               502.0                               602.0
#
#    ...  Cyto_Texture_Variance_Mito_10_02_256  \
# 0  ...                             33.402145
# 1  ...                             21.517467
# 2  ...                             18.503750
# 3  ...                             19.896962
# 4  ...                             51.358578
#
#    Cyto_Texture_Variance_Mito_10_03_256  Cyto_Texture_Variance_Mito_3_00_256  \
# 0                             34.362640                            32.764223
# 1                             22.041616                            20.282188
# 2                             19.005039                            17.839701
# 3                             20.077885                            19.813550
# 4                             51.549896                            49.833778
#
#    Cyto_Texture_Variance_Mito_3_01_256  Cyto_Texture_Variance_Mito_3_02_256  \
# 0                            32.971792                            33.131979
# 1                            20.300323                            20.689981
# 2                            17.912834                            17.765783
# 3                            19.387311                            19.642703
# 4                            49.990757                            50.283543
#
#    Cyto_Texture_Variance_Mito_3_03_256  Cyto_Texture_Variance_Mito_5_00_256  \
# 0                            32.626884                            32.644241
# 1                            20.434265                            20.318130
# 2                            17.722588                            17.731947
# 3                            19.443669                            19.278375
# 4                            49.137386                            49.736687
#
#    Cyto_Texture_Variance_Mito_5_01_256  Cyto_Texture_Variance_Mito_5_02_256  \
# 0                            33.476397                            33.115974
# 1                            20.990555                            20.547068
# 2                            18.489265                            17.798031
# 3                            19.548204                            19.337269
# 4                            50.390118                            49.221760
#
#    Cyto_Texture_Variance_Mito_5_03_256
# 0                            33.198650
# 1                            20.693096
# 2                            17.842939
# 3                            19.203957
# 4                            49.895370
#
# [5 rows x 2981 columns]

# %% [markdown]
# # Load EOS number

# %%
file_type = '/*[0-9]_' + 'Annotation_USC_HepG2.csv'
files = glob.glob(annot_path + file_type)

### gets latest file
max_file = max(files, key=os.path.getctime)

### load file
Annotation_Bioactives = pd.read_csv(max_file)
Annotation_Bioactives.shape
# Out:
# (10752, 6)

# %%
Annotation_Bioactives.head()
# Out:
#   Metadata_Plate Metadata_Well Metadata_EOS  Metadata_Concentration  \
# 0          B1001           A01    EOS100001                      10
# 1          B1001           C01    EOS100002                      10
# 2          B1001           E01    EOS100003                      10
# 3          B1001           G01    EOS100004                      10
# 4          B1001           I01    EOS100005                      10
#
#   Metadata_Partner Metadata_Batch
# 0       Bioactives             R1
# 1       Bioactives             R1
# 2       Bioactives             R1
# 3       Bioactives             R1
# 4       Bioactives             R1

# %% [markdown]
# # Merge with EOS number

# %%
Data_Bioactives = pd.merge(
    Annotation_Bioactives, 
    Data_aggregated, 
    on = ["Metadata_Batch", "Metadata_Plate", "Metadata_Well"], 
    how = "inner")
        
print("Aggregated and annotated Data has shape ", Data_Bioactives.shape)
# Out:
# Aggregated and annotated Data has shape  (10747, 2984)

# %%
Data_Bioactives.head()
# Out:
#   Metadata_Plate Metadata_Well Metadata_EOS  Metadata_Concentration  \
# 0          B1001           A01    EOS100001                      10
# 1          B1001           C01    EOS100002                      10
# 2          B1001           E01    EOS100003                      10
# 3          B1001           G01    EOS100004                      10
# 4          B1001           I01    EOS100005                      10
#
#   Metadata_Partner Metadata_Batch  Metadata_Object_Count  Nuc_AreaShape_Area  \
# 0       Bioactives             R1                   1188               548.0
# 1       Bioactives             R1                   1384               535.0
# 2       Bioactives             R1                   1747               486.0
# 3       Bioactives             R1                   1707               503.0
# 4       Bioactives             R1                   1756               461.5
#
#    Nuc_AreaShape_BoundingBoxArea  Nuc_AreaShape_BoundingBoxMaximum_X  ...  \
# 0                          750.0                               567.0  ...
# 1                          750.0                               560.0  ...
# 2                          675.0                               567.0  ...
# 3                          700.0                               576.0  ...
# 4                          648.0                               531.0  ...
#
#    Cyto_Texture_Variance_Mito_10_02_256  Cyto_Texture_Variance_Mito_10_03_256  \
# 0                             33.402145                             34.362640
# 1                             31.475841                             32.555525
# 2                             37.585041                             38.161564
# 3                             33.361671                             33.819366
# 4                             21.040535                             21.487117
#
#    Cyto_Texture_Variance_Mito_3_00_256  Cyto_Texture_Variance_Mito_3_01_256  \
# 0                            32.764223                            32.971792
# 1                            30.891366                            30.671321
# 2                            37.197063                            37.375050
# 3                            32.438019                            32.244225
# 4                            20.593282                            20.500590
#
#    Cyto_Texture_Variance_Mito_3_02_256  Cyto_Texture_Variance_Mito_3_03_256  \
# 0                            33.131979                            32.626884
# 1                            30.928588                            30.709328
# 2                            36.939110                            36.417900
# 3                            32.639027                            31.949083
# 4                            20.750995                            20.509786
#
#    Cyto_Texture_Variance_Mito_5_00_256  Cyto_Texture_Variance_Mito_5_01_256  \
# 0                            32.644241                            33.476397
# 1                            30.664491                            31.131104
# 2                            36.842789                            37.464584
# 3                            32.298512                            32.378819
# 4                            20.458314                            20.706921
#
#    Cyto_Texture_Variance_Mito_5_02_256  Cyto_Texture_Variance_Mito_5_03_256
# 0                            33.115974                            33.198650
# 1                            30.600011                            30.878704
# 2                            36.643440                            36.628403
# 3                            32.414738                            32.015900
# 4                            20.558457                            20.689795
#
# [5 rows x 2984 columns]

# %% [markdown]
# # Save raw data

# %%
### 
filename = save_path + str(date.today()) + "_USC_HepG2_raw.csv"
Data_Bioactives.to_csv(filename, index = False)

# %% [markdown]
# ## Save missing data

# %%
Data_Bioactives_missing = pd.merge(
    Annotation_Bioactives, 
    Data_aggregated, 
    on = ["Metadata_Batch", "Metadata_Plate", "Metadata_Well"], 
    how = "left",
    indicator = True)
        
Data_Bioactives_missing = Data_Bioactives_missing[Data_Bioactives_missing["_merge"] == 'left_only'].dropna(axis='columns')

# %%
### 
filename = save_path + str(date.today()) + "_USC_HepG2_raw_missing_wells.csv"
Data_Bioactives_missing.to_csv(filename, index = False)

# %%
print("There are",len(Data_Bioactives_missing), "missing wells.")
# Out:
# There are 5 missing wells.

# %%
Data_Bioactives_missing_counts = Data_Bioactives_missing['Metadata_EOS'].value_counts()
print("There are",len(Data_Bioactives_missing_counts[Data_Bioactives_missing_counts.iloc[:] == 4]), "compounds missing all 4 replicates.")
# Out:
# There are 0 compounds missing all 4 replicates.
